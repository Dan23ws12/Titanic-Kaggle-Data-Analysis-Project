# %%
print("week")
# Out:
# week

# %%
import pandas as pd
import numpy as np
import matplotlib as mp
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
train2 = pd.read_excel(r"C:\Users\danie\Documents\data projects\Titanic data analysis\train2.xlsx")

# %%
train2
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
train2.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
train2.info()
train2.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
train2_cln = train2.dropna(subset = train2.columns.values.tolist())

# %%
train2_cln.info()
train2_cln.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 712 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  712 non-null    int64
#  1   Pclass    712 non-null    int64
#  2   Sex       712 non-null    object
#  3   Age       712 non-null    float64
#  4   SibSp     712 non-null    int64
#  5   Parch     712 non-null    int64
#  6   Fare      712 non-null    float64
#  7   Embarked  712 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 50.1+ KB
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
survive_bins = [float('-Inf'), 0.5, float('Inf')]
survive_labels = ["didn't survive", "survive"]
train2_cln["Survived"] = pd.cut(train2_cln["Survived"],bins=survive_bins, labels = survive_labels)
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_14996\1731158429.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train2_cln["Survived"] = pd.cut(train2_cln["Survived"],bins=survive_bins, labels = survive_labels)

# %%
train2_cln.head()
# Out:
#          Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  \
# 0  didn't survive       3    male  22.0      1      0   7.2500        S
# 1         survive       1  female  38.0      1      0  71.2833        C
# 2         survive       3  female  26.0      0      0   7.9250        S
# 3         survive       1  female  35.0      1      0  53.1000        S
# 4  didn't survive       3    male  35.0      0      0   8.0500        S
#
#            status
# 0  didn't survive
# 1         survive
# 2         survive
# 3         survive
# 4  didn't survive

# %%
pclass_bins = [0, 1,2, 3]
pclass_labels = ["First", "Second", "Third"]
train2_cln["status"] = pd.cut(x=train2_cln["Pclass"], bins = pclass_bins, labels = pclass_labels, right = True)
train2_cln.head()
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_14996\1239717568.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train2_cln["status"] = pd.cut(x=train2_cln["Pclass"], bins = pclass_bins, labels = pclass_labels, right = True)
#          Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked status
# 0  didn't survive       3    male  22.0      1      0   7.2500        S  Third
# 1         survive       1  female  38.0      1      0  71.2833        C  First
# 2         survive       3  female  26.0      0      0   7.9250        S  Third
# 3         survive       1  female  35.0      1      0  53.1000        S  First
# 4  didn't survive       3    male  35.0      0      0   8.0500        S  Third
